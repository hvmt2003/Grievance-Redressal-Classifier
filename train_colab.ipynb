# %% [markdown]
# # UP Grievance Classifier Training
#
# Run this notebook to retrain the model on Google Colab's GPU.
#
# ## Step 1: Upload `project_code.zip`
# Upload the `project_code.zip` file created in your project directory to the Files section (left sidebar).

# %%
# !unzip -o project_code.zip

# %% [markdown]
# ## Step 2: Install Dependencies

# %%
# !pip install torch transformers scikit-learn pandas numpy

# %% [markdown]
# ## Step 3: Run Training (10 Epochs)

# %%
# !python -m src.train --epochs 10

# %% [markdown]
# ## Step 4: Download Model

# %%
# !zip -r trained_model.zip best_model_state.bin category_map.npy priority_map.npy
from google.colab import files
files.download('trained_model.zip')
